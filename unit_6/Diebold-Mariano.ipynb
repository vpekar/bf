# %% [markdown]
# Installation:
#
# pip install git+https://github.com/vpekar/Diebold-Mariano-Test.git@patch-1

# %%
from dm_test import dm_test

true_values = [10, 20, 30, 40, 50]
forecast1 = [11, 21, 29, 42, 53]
forecast2 = [13, 26, 24, 44, 59]

rt = dm_test(true_values, forecast1, forecast2, h=1, crit="MSE")
rt.p_value
# Out:
# np.float64(0.04661256496853764)
